# %%
# !git clone https://github.com/danhtran2mind/MotionDirector
# %cd MotionDirector

# %%
# !pip install -r requirements.txt -q
# Out:
# /content
# Cloning into 'MotionDirector'...
# remote: Enumerating objects: 666, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 666 (delta 112), reused 87 (delta 81), pack-reused 494 (from 1)
# Receiving objects: 100% (666/666), 132.29 MiB | 30.50 MiB/s, done.
# Resolving deltas: 100% (353/353), done.
# /content/MotionDirector
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 32.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 112.3 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import HfApi
from huggingface_hub import snapshot_download
import os
api = HfApi()

# repo_id = "heboya8/zeroscope_v2_576w-Scenery_Anime_Bright-256-lora"
repo_id = "danhtran2mind/zeroscope_v2_576w-Ghibli-LoRA"
save_path = "./ckpts/zeroscope_v2_576w-Ghibli-LoRA"

# Create the directory if it doesn't exist
os.makedirs(save_path, exist_ok=True)

# Download the dataset
snapshot_download(repo_id=repo_id, repo_type="model", local_dir=save_path)
# Out:
# '/content/MotionDirector/ckpts/zeroscope_v2_576w-Ghibli-LoRA'

# %%
import os
os.makedirs("./ckpts/zeroscope_v2_576w", exist_ok=True)

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
repo_id = repo_id = "cerspense/zeroscope_v2_576w"
save_path = "./ckpts/zeroscope_v2_576w"

# Create the directory if it doesn't exist
os.makedirs(save_path, exist_ok=True)

# Download the dataset
snapshot_download(repo_id=repo_id, repo_type="model", local_dir=save_path)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/681M [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# text2video_pytorch_model.pth:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# ...

# %%
# Inference
# !python main_inference.py \
    --model "./ckpts/zeroscope_v2_576w" \
    --checkpoint_folder "./ckpts/zeroscope_v2_576w-Ghibli-LoRA" \
    --prompt "Studio Ghibli style. Two women walk down coastal village path toward sea, passing colorful houses, sailboats visible." \
    --negative-prompt "ugly, noise, fragment, blur, static video" \
    --width 512 --height 512 \
    --num-frames 16 \
    --num-steps 50 \
    --guidance-scale 30 \
    --fps 16 \
    --lora_rank 96 \
    --lora_scale 0.7 \
    --noise_prior 0.1 \
    --device "$device" \
    --seed 100
    # --no_prompt_name
# Out:
# 2025-07-21 13:28:45.811590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753104526.058892    2521 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753104526.125137    2521 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-21 13:28:46.677768: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from IPython.display import Video
Video('./outputs/inference/Studio_Ghibli_style_Two_women_walk_down_coastal_village_path_toward_sea_passing_colorful_houses_sailboats_visible_100.mp4',
      embed=True, width=512, height=512)
# Out:
# <video controls  width="512"  height="512">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
